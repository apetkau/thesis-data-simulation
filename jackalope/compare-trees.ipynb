# %%
library(ape)
library(phytools)
library(phangorn)
library(repr)

t_orig <- read.tree(file="input/salmonella.tre")
t_new <- read.tree(file="phylogeny/core.aln.treefile")

t_orig <- root(t_orig, "reference", resolve.root=TRUE)
t_new <- root(t_new, "Reference", resolve.root=TRUE)

comparePhylo(t_orig, t_new, plot=TRUE)
# Out:
# Warning message in file(file, "r"):
# "cannot open file 'phylogeny/core.aln.treefile': No such file or directory"
# Error in file(file, "r"): cannot open the connection
# Traceback:
#
# 1. read.tree(file = "phylogeny/core.aln.treefile")
# 2. scan(file = file, what = "", sep = "\n", quiet = TRUE, skip = skip,
#  .     comment.char = comment.char, ...)
# 3. file(file, "r")

# %%
treedist(t_orig, t_new, check.labels = TRUE)
# Out:
# Error in checkLabels(tree2, tree1$tip.label): tree has different labels
# Traceback:
#
# 1. treedist(t_orig, t_new, check.labels = TRUE)
# 2. checkLabels(tree2, tree1$tip.label)
# 3. stop("tree has different labels")

# %%
options(repr.plot.width=10, repr.plot.height=8)

plot(cophylo(t_orig, t_new, rotate=TRUE))
# Out:
# Rotating nodes to optimize matching...
# Done.
# plot without title
